# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
# Function to remove stop words from tweets
def remove_stoppers(text):
    stop_words = set(stopwords.words('english'))
    word_tokens = word_tokenize(text)
    filtered_sentence = [w for w in word_tokens if not w in stop_words]
    return filtered_sentence

# %%
# Import the text files containing the tweets
dataset_stress = open("stress_covid.txt", "r").read()
dataset_sleep = open("sleep_covid.txt", "r").read()

# %%
#convert list to string and generate
unique_string=(" ").join(new)
wordcloud = WordCloud(width = 1000, height = 500, max_words = 100).generate(unique_string)
plt.figure(figsize=(15,8))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()
plt.close()
